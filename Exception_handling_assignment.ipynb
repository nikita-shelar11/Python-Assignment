# %% [markdown]
# # Exception Handling Assignment

# %%
#1. Write a Python program to handle a ZeroDivisionError exception when dividing a number by zero.

try:
    num = int(input("Enter numerator:"))
    den = int(input("Enter denominator:"))
    division = num/den
    print(division)
except ZeroDivisionError:
    print("Cannot divide by zero!")
# Out:
# Enter numerator: 10
# Enter denominator: 0
# Cannot divide by zero!

# %%
#2. Write a Python program that prompts the user to input an integer and raises a ValueError exception if the input is not a valid integer.

try:
    num = int(input("Enter a number:"))
except ValueError:
    print("Please enter valid integers!")
# Out:
# Enter a number: 2

# %%
#3. Write a Python program that opens a file and handles a FileNotFoundError exception if the file does not exist.

try:
    f = open("sampl.txt","r")
    print(f.read())
except FileNotFoundError:
    print("Oops! No such file or directory: 'sampl.txt'")
# Out:
# Oops! No such file or directory: 'sampl.txt'

# %%
#4. Write a Python program that prompts the user to input two numbers and raises a TypeError exception if the inputs are not numerical.

try:
    num1 = input("Enter first number:")
    num2 = input("Enter second number:")
    if not (num1.isdigit() and num2.isdigit()):
        raise TypeError("Please enter numeric value")
    
    
    result = int(num1) + int(num2)
    print(result)

except TypeError as e:
    print("TypeError:",e)
# Out:
# Enter first number: er
# Enter second number: fh
# TypeError: Please enter numeric value

# %%
#5. Write a Python program that opens a file and handles a PermissionError exception if there is a permission issue.

# %%
#6. Write a Python program that executes an operation on a list and handles an IndexError exception if the index is out of range.

try:
    L = [1,2,3]
    print(L[3])
except IndexError:
    print("Index is out of range")
# Out:
# Index is out of range

# %%
#7. Write a Python program that executes division and handles an ArithmeticError exception if there is an arithmetic error.

try:
    num = int(input("Enter numerator:"))
    den = int(input("Enter denominator:"))
    division = num/den
    print(division)
except ArithmeticError:
    print("Arithmetic error occurred")
# Out:
# Enter numerator: 3
# Enter denominator: 0
# Arithmetic error occurred
